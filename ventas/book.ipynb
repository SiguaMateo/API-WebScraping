# %%
import pandas as pd

# %%
# Leer y mostrar el archivo CSV
df = pd.read_csv("../ventas.csv")
df.head()
# Out:
#    Week (invoice date ) Invoice date  \
# 0                  48.0   2023-11-29
# 1                  48.0   2023-11-29
# 2                  48.0   2023-11-29
# 3                  47.0   2023-11-25
# 4                  47.0   2023-11-25
#
#                              Customer group Invoice number  \
# 0                   Delivery at IP Handlers            933
# 1                   Delivery at IP Handlers            935
# 2                   Delivery at IP Handlers            928
# 3  Invoice Direct delivered by BSI Aaslmeer            914
# 4  Invoice Direct delivered by BSI Aaslmeer            916
#
#                       Customer Country of client  \
# 0              EN Flowers Srl.             Italy
# 1                   CZS d.o.o.          Slovenia
# 2                   Green Soho            Poland
# 3  Enigma Flowers Trading B.V.       Netherlands
# 4                 Dir.Flor Srl             Italy
#
#                         Product           Colour  \
# ...
